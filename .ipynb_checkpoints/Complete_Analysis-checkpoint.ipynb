# %% [markdown]
# # Step 1: Get tweets and find their location

# %%
import numpy as np
import pandas as pd
import warnings
import math
warnings.filterwarnings('ignore')

tweets = pd.read_csv("output_got.csv", sep=None, error_bad_lines=False, warn_bad_lines=False)

us_states= {
    'Alabama': ['AL', 'Al'],
    'Alaska': ['AK', 'Ak'],
    'Arizona': ['AZ', 'Az'],
    'Arkansas': ['AR', 'Ar'],
    'California': ['CA', 'Ca'],
    'Colorado': ['CO', 'Co'],
    'Connecticut': ['CT', 'Ct'],
    'Delaware': ['DE', 'De'],
    'District Of Columbia': ['DC', 'D.C.','Washington, DC', 'Washington, D.C.', 'Washington DC',
                            'Washington D.C.', 'WASH. D.C.'],
    'Florida': ['FL', 'Fl'],
    'Georgia': ['GA', 'Ga'],
    'Hawaii': ['HI', 'Hi'],
    'Idaho': ['ID', 'Id'],
    'Illinois': ['IL', 'Il'],
    'Indiana': ['IN'],
    'Iowa': ['IA', 'Ia'],
    'Kansas': ['KS', 'Ks'],
    'Kentucky': ['KY', 'Ky'],
    'Louisiana': ['LA', 'La'],
    'Maine': ['ME', 'Me'],
    'Maryland': ['MD', 'Md'],
    'Massachusetts': ['MA', 'Ma'],
    'Michigan': ['MI', 'Mi'],
    'Minnesota': ['MN', 'Mn'],
    'Mississippi': ['MS', 'Ms'],
    'Missouri': ['MO', 'Mo'],
    'Montana': ['MT', 'Mt'],
    'Nebraska': ['NE', 'Ne'],
    'Nevada': ['NV', 'Ne'],
    'New Hampshire': ['NH', 'Nh'],
    'New Jersey': ['NJ', 'Nj'],
    'New Mexico': ['NM', 'Nm'],
    'New York': ['NY', 'Ny'],
    'North Carolina': ['NC', 'Nc'],
    'North Dakota': ['ND', 'Nd'],
    'Ohio': ['OH', 'Oh'],
    'Oklahoma': ['OK', 'Ok'],
    'Oregon': ['OR', 'Or'],
    'Pennsylvania': ['PA', 'Pa'],
    'Rhode Island': ['RI', 'Ri'],
    'South Carolina': ['SC', 'Sc'],
    'South Dakota': ['SD', 'Sd'],
    'Tennessee': ['TN', 'Tn'],
    'Texas': ['TX', 'Tx'],
    'Utah': ['UT', 'Ut'],
    'Vermont': ['VT', 'Vt'],
    'Virginia': ['VA', 'Va'],
    'Washington': ['WA', 'Wash.', 'Wash', 'Washington State', 'Wa'],
    'West Virginia': ['WV', 'Wv'],
    'Wisconsin': ['WI', 'Wi'],
    'Wyoming': ['WY', 'Wy'],
}

locations = tweets['Geo'].tolist()

#Number of tweets from each state
state_counts = {state: 0 for state in us_states}

cleaned_locations = []

for idx, tweet in tweets.iterrows():
    location= tweet['Geo']
    if type(location) is str: #make sure its not nan
        found_state = False
        d = {'Text':tweet['Text'], 'Hashtags': tweet['Hashtags']}
        for key, values in us_states.items():
            if key.lower() in location.lower():
#                 print (location)
#                 print (key)
#                 print ()
                found_state = True
                state_counts[key] += 1
                d['Location'] = key
                cleaned_locations.append(d)
                break
            else:
                for value in values:
                    if len(value) == 2:
                        if value in location.replace(',','').split():
#                             print (location)
#                             print (value)
#                             print ()
                            found_state = True
                            state_counts[key] +=1
                            d['Location'] = key
                            cleaned_locations.append(d)
                            break
                    elif value in location:
#                         print (location)
#                         print (value)
#                         print ()
                        found_state = True
                        state_counts[key] += 1
                        d['Location'] = key
                        cleaned_locations.append(d)
                        break
                    elif len(value) > 2 and value.lower() in location.lower():
#                         print (location)
#                         print (value)
#                         print ()
                        found_state = True
                        state_counts[key] +=1
                        d['Location'] = key
                        cleaned_locations.append(d)
                        break
            if found_state == True:
                break
                
tweets = pd.DataFrame(cleaned_locations)

print (state_counts)
print ()
print ("Number of tweets from US states:", len(tweets.index))
# Out:
# {'Alabama': 34, 'Alaska': 4, 'Arizona': 70, 'Arkansas': 54, 'California': 674, 'Colorado': 164, 'Connecticut': 91, 'Delaware': 13, 'District Of Columbia': 327, 'Florida': 347, 'Georgia': 100, 'Hawaii': 16, 'Idaho': 20, 'Illinois': 150, 'Indiana': 75, 'Iowa': 29, 'Kansas': 40, 'Kentucky': 30, 'Louisiana': 46, 'Maine': 16, 'Maryland': 80, 'Massachusetts': 152, 'Michigan': 91, 'Minnesota': 45, 'Mississippi': 11, 'Missouri': 67, 'Montana': 13, 'Nebraska': 8, 'Nevada': 44, 'New Hampshire': 22, 'New Jersey': 92, 'New Mexico': 34, 'New York': 668, 'North Carolina': 140, 'North Dakota': 4, 'Ohio': 124, 'Oklahoma': 18, 'Oregon': 104, 'Pennsylvania': 121, 'Rhode Island': 10, 'South Carolina': 31, 'South Dakota': 3, 'Tennessee': 53, 'Texas': 303, 'Utah': 16, 'Vermont': 26, 'Virginia': 179, 'Washington': 139, 'West Virginia': 1, 'Wisconsin': 35, 'Wyoming': 3}
#
# Number of tweets from US states: 4937

# %% [markdown]
# # Step 2: Web Scrape from StatusOfWomen.org to get state rankings in each womens issue

# %%
from bs4 import BeautifulSoup
from pandas import DataFrame as dataF
import requests
import time

url = "https://statusofwomendata.org/state-data/"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36"}
stateNames = []
employmentEarn = []
politicalPart = []
povertyOpp = []
reprodRights = []
healthWell = []
workFam = []

page = requests.get(url, headers=headers)
time.sleep(0.5)
soup = BeautifulSoup(page.text, "lxml")
statesList = soup.find("article", class_="post").find_all("p")

for state in statesList:
    statePage = requests.get(state.find("a").get("href"), headers=headers)
    time.sleep(0.5)
    stateSoup = BeautifulSoup(statePage.text, "lxml")
    name = stateSoup.find("div", class_="state").find("h1").text
    stateNames.append(name)
    
    reportCard = stateSoup.find("div", class_="cardSummary").find_all("tr")[1:]
    employmentEarn.append(reportCard[0].find_all("td")[1].text)
    if(reportCard[1].find_all("td")[1].text == "-"):
        politicalPart.append("0")
    else:
        politicalPart.append(reportCard[1].find_all("td")[1].text)
    povertyOpp.append(reportCard[2].find_all("td")[1].text)
    reprodRights.append(reportCard[3].find_all("td")[1].text)
    healthWell.append(reportCard[4].find_all("td")[1].text)
    workFam.append(reportCard[5].find_all("td")[1].text)

# %% [markdown]
# # Step 3: Write each state's ranking as well as tweets per person into state_rankings.csv

# %%
populations = {'Alabama': 4863300,
    'Alaska': 741894,
    'Arizona': 6931071,
    'Arkansas': 2988248,
    'California': 39250017,
    'Colorado': 5540545,
    'Connecticut': 	3576452,
    'Delaware': 952065,
    'District Of Columbia': 681170,
    'Florida': 20612439,
    'Georgia': 10310371,
    'Hawaii': 1428557,
    'Idaho': 1683140,
    'Illinois': 12801539,
    'Indiana': 6633053,
    'Iowa': 3134693,
    'Kansas': 2907289,
    'Kentucky': 4436974,
    'Louisiana': 4681666,
    'Maine': 1331479,
    'Maryland': 6016447,
    'Massachusetts': 6811779,
    'Michigan': 9928300,
    'Minnesota': 5519952,
    'Mississippi': 2988726,
    'Missouri': 6093000,
    'Montana': 1042520,
    'Nebraska': 1907116,
    'Nevada': 2940058,
    'New Hampshire': 1334795,
    'New Jersey': 8944469,
    'New Mexico': 2081015,
    'New York': 19745289,
    'North Carolina': 10146788,
    'North Dakota': 757952,
    'Ohio': 11614373,
    'Oklahoma': 3923561,
    'Oregon': 4093465,
    'Pennsylvania': 12784227,
    'Rhode Island': 1056426,
    'South Carolina': 4961119,
    'South Dakota': 865454,
    'Tennessee': 6651194,
    'Texas': 27862596,
    'Utah': 3051217,
    'Vermont': 624594,
    'Virginia': 8411808,
    'Washington': 7288000,
    'West Virginia': 1831102,
    'Wisconsin': 5778708,
    'Wyoming': 585501,
}

for state, count in state_counts.items():
    population = populations[state]
    state_counts[state] = (state_counts[state]/population)

state_counts_df = pd.DataFrame(list(state_counts.items()), columns=['Name', 'Tweets Per Person'])

stateRankings = dataF({"Name": stateNames, "Employment & Earnings": employmentEarn, "Political Participation": politicalPart, "Poverty & Opportunity": povertyOpp, "Reproductive Rights": reprodRights, "Health & Well-Being": healthWell, "Work & Family": workFam})
stateRankings = stateRankings[["Name","Employment & Earnings", "Political Participation", "Poverty & Opportunity","Reproductive Rights", "Health & Well-Being", "Work & Family"]]

stateRankings.loc[stateRankings['Name'] == 'District Of Columbia', 'Political Participation'] = 25


stateRankings = stateRankings.merge(state_counts_df, on="Name")
print (stateRankings.head(5))
stateRankings.to_csv("state_rankings.csv", index=False)
# Out:
#          Name Employment & Earnings Political Participation  \
# 0     Alabama                    46                      41
# 1      Alaska                     7                      33
# 2     Arizona                    34                      14
# 3    Arkansas                    47                      47
# 4  California                    15                       8
#
#   Poverty & Opportunity Reproductive Rights Health & Well-Being Work & Family  \
# 0                    45                  40                  50            39
# 1                    12                  29                  27            15
# 2                    35                  24                  28            38
# 3                    50                  43                  47             8
# 4                    23                   9                  17             2
#
#    Tweets Per Person
# 0           0.000007
# 1           0.000005
# 2           0.000010
# 3           0.000018
# 4           0.000017

# %% [markdown]
# # Step 4: Perform linear regression on state_rankings.csv to see which womens issue has the most influence on the number of tweets per state

# %%
import pandas as pd
from pandas import DataFrame as df
from pandas import Series as sr
import numpy as np
import matplotlib.pyplot as plt

import statsmodels.api as sm
from sklearn.linear_model import LinearRegression as lr

# %%
data = pd.read_csv("state_rankings.csv")

data.index = data.Name
data.drop("Name", axis=1, inplace=True)
data.sample(5)
# Out:
#                Employment & Earnings  Political Participation  \
# Name
# Michigan                          36                       15
# New Jersey                         4                       31
# Maryland                           2                       18
# Massachusetts                      3                        5
# Louisiana                         49                       46
#
#                Poverty & Opportunity  Reproductive Rights  \
# Name
# Michigan                          26                   45
# New Jersey                        11                    4
# Maryland                           2                    3
# Massachusetts                      3                   14
# Louisiana                         47                   46
#
#                Health & Well-Being  Work & Family  Tweets Per Person
# Name
# Michigan                        36             44           0.000009
# New Jersey                      13              4           0.000010
# Maryland                        26             22           0.000013
# Massachusetts                    9             24           0.000022
# Louisiana                       49             20           0.000010

# %%
x = data.values[:, :6]
y = data.values[:, 6]

fig, axes = plt.subplots(2, 3, figsize=(10, 6))

for i in range(6):
    j = i//3
    k = i%3
    axes[j][k].scatter(x[:, i].reshape(-1, 1), y)
    axes[j][k].set_title(data.columns[i])
plt.show()

# %% [markdown]
# ### all attributes:

# %%
model = sm.OLS(y, x)
result = model.fit()
param_ref = result.params
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.361
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     4.236
# Date:                Sat, 09 Dec 2017   Prob (F-statistic):            0.00184
# Time:                        15:41:44   Log-Likelihood:                 427.83
# No. Observations:                  51   AIC:                            -843.7
# Df Residuals:                      45   BIC:                            -832.1
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          2.148e-06   1.82e-06      1.181      0.244   -1.52e-06    5.81e-06
# x2          2.777e-07   6.92e-07      0.401      0.690   -1.12e-06    1.67e-06
# x3         -4.749e-06   1.87e-06     -2.545      0.014   -8.51e-06   -9.91e-07
# x4          2.938e-09   7.59e-07      0.004      0.997   -1.53e-06    1.53e-06
# x5          3.264e-06   7.57e-07      4.313      0.000    1.74e-06    4.79e-06
# x6         -2.963e-07    6.7e-07     -0.442      0.660   -1.65e-06    1.05e-06
# ==============================================================================
# Omnibus:                       72.277   Durbin-Watson:                   2.264
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              855.323
# Skew:                           3.682   Prob(JB):                    1.86e-186
# Kurtosis:                      21.662   Cond. No.                         21.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### one attribute at a time

# %%
for i in range(6):
    model2 = lr()
    model2.fit(x[:, i].reshape(-1, 1), y)
    model2.predict(x[:, i].reshape(-1, 1))
    print(data.columns[i], "r-squared score:")
    print(model2.score(x[:, i].reshape(-1, 1), y))
# Out:
# Employment & Earnings r-squared score:
# 0.0876057284031
# Political Participation r-squared score:
# 0.0022466142263
# Poverty & Opportunity r-squared score:
# 0.0843783123542
# Reproductive Rights r-squared score:
# 0.0547997525364
# Health & Well-Being r-squared score:
# 0.0326940423712
# Work & Family r-squared score:
# 0.0672472448045

# %% [markdown]
# ### attribute's influence

# %%
for i in range(6):
    param_ref_temp = np.delete(param_ref, i, 0)
    model = sm.OLS(y, np.delete(x, i, 1))
    result = model.fit()
    param_ref1 = result.params
    print(data.columns[i]+"\'s influence:")
    print(sum(np.divide(abs(param_ref1 - param_ref_temp), abs(param_ref_temp))))
# Out:
# Employment & Earnings's influence:
# 54.989514484
# Political Participation's influence:
# 32.0904510397
# Poverty & Opportunity's influence:
# 9.79181194251
# Reproductive Rights's influence:
# 0.00683202087732
# Health & Well-Being's influence:
# 31.1539802919
# Work & Family's influence:
# 42.6799300535

# %%
import pandas as pd
import numpy as np

# from matplotlib import pyplot as plt
import matplotlib

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.feature_extraction import text
from sklearn.decomposition import LatentDirichletAllocation,TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import RegexpTokenizer
from sklearn.metrics import silhouette_score

import warnings
import math
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step 5: Kmeans Clustering

# %%
state_ranks_df = pd.read_csv("state_rankings.csv")
state_ranks_df.index = state_ranks_df.Name
state_ranks_df.drop(["Name","Tweets Per Person"], axis=1, inplace=True)
state_ranks_df.head(5)
# Out:
#             Employment & Earnings  Political Participation  \
# Name
# Alabama                        46                       41
# Alaska                          7                       33
# Arizona                        34                       14
# Arkansas                       47                       47
# California                     15                        8
#
#             Poverty & Opportunity  Reproductive Rights  Health & Well-Being  \
# Name
# Alabama                        45                   40                   50
# Alaska                         12                   29                   27
# Arizona                        35                   24                   28
# Arkansas                       50                   43                   47
# California                     23                    9                   17
#
#             Work & Family
# Name
# Alabama                39
# Alaska                 15
# Arizona                38
# Arkansas                8
# California              2

# %%
n_topics = 4

def get_kmeans(data, k, scale=True):
    if scale:
        s = MinMaxScaler()
        data = s.fit_transform(data)
    
    m = KMeans(n_clusters=k, random_state=0).fit(data)
    d = m.predict(data)
    return m, d        

kmean_m, kmean_d = get_kmeans(state_ranks_df, n_topics, scale=False)

# %%
state_ranks_df['Cluster'] = kmean_m.labels_.tolist()
state_ranks_df.head(5)
# Out:
#             Employment & Earnings  Political Participation  \
# Name
# Alabama                        46                       41
# Alaska                          7                       33
# Arizona                        34                       14
# Arkansas                       47                       47
# California                     15                        8
#
#             Poverty & Opportunity  Reproductive Rights  Health & Well-Being  \
# Name
# Alabama                        45                   40                   50
# Alaska                         12                   29                   27
# Arizona                        35                   24                   28
# Arkansas                       50                   43                   47
# California                     23                    9                   17
#
#             Work & Family  Cluster
# Name
# Alabama                39        2
# Alaska                 15        0
# Arizona                38        3
# Arkansas                8        2
# California              2        0

# %% [markdown]
# # Step 6: LDA

# %%
# Sort by clusters and get list of the states in each one
state_ranks_df = state_ranks_df.sort_values('Cluster')

clusterlists = []
for i in range(n_topics):    
    df = state_ranks_df[state_ranks_df['Cluster'] == i]
    clusterlists.append(df.index.tolist())

# Tweets df has Hashtags, Location, Text
# Get list of the texts from all the states in each cluster
textlists = []
for i in range(n_topics):
    df = tweets[tweets['Location'].isin(clusterlists[i])]
    textlists.append(df.Text.tolist())

#Words to ignore
stop_words = text.ENGLISH_STOP_WORDS.union(frozenset(['http','https', 'don', 'gl','www','twitter', 
                                                      'got','bit','women', 'woman', 'like', 'thank', 'instagram', 'fb', 'ly', 
                                                      'goo', 'status', 'atus', 'st', 'tatus','repost', 'did', 'sta', 'tus', 'youtu', 
                                                      'com', 'pic','statu', 'facebook', 'youtube', 'li', 'll', '01', '2017', 
                                                      'make', 'let', 'need', '31', 'rt', 'ln', 'html']))
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
    
def LDA(documents, max_df=0.95, min_df=2, max_features=1000, n_topics=20, n_top_words=10):
    '''
     tf_vectorizer:
       - Strips out “stop words”
       - Filters out terms that occur in more than 95% of the docs (max_df=0.95)
       - Filters out terms that occur in only one document (min_df=2).
       - Selects the 1,000 most frequently occuring words in the corpus.
       - Normalizes the vector (L2 norm of 1.0) to normalize the effect of 
         document length on the tf_vectorizer values. 
    '''
    tf_vectorizer = CountVectorizer(max_df=max_df, min_df=min_df, max_features=max_features, stop_words=stop_words)
    tf = tf_vectorizer.fit_transform(documents)
    tf_feature_names = tf_vectorizer.get_feature_names()
    
    lda = LatentDirichletAllocation(n_topics=n_topics, max_iter=20, learning_method='online', \
                                    learning_offset=50.,random_state=0).fit(tf)

    display_topics(lda, tf_feature_names, n_top_words)
#     print (lda.transform(tf))

ldalist = []
for i in range(n_topics):
    print('Performing LDA on Cluster', str(i) + '...')
    lda = LDA(textlists[i])
    ldalist.append(lda)
    print()
# Out:
# Performing LDA on Cluster 0...
# Topic 0:
# trump vote madonna president muslimban yes donald congress anti protests
# Topic 1:
# share thoughts dear children snowflakes organizers inspiration meet continues supported
# Topic 2:
# nobannowall muslimban protest resist realdonaldtrump america nomuslimban potus nodapl sciencemarch
# Topic 3:
# resist resistance rights stat just support whyimarch postcards weekend looks
# Topic 4:
# womensrights feminism 50 sharia learn huffingtonpost intersectional group dc committed
# Topic 5:
# time history postcard heard senators 100 voices send source itâ
# Topic 6:
# right new thing didn democrats bad far antitrump come justice
# Topic 7:
# fight cover oh fighting newyorker friend los really new tell
# Topic 8:
# week people hope marching way amazing feminists shirt hey action
# Topic 9:
# etsy marched pink hat pussy power pussyhat hats sundaymorning podcast
# Topic 10:
# marchforlife maga abortion plannedparenthood live liberal ppact fakenews omg liberals
# Topic 11:
# broemmel ref girl amazon resist sr keywords utf8 qid bonfils
# Topic 12:
# muslimban muslim nobannowall news refugeeswelcome day ban 11e6 usa things
# Topic 13:
# nyc 10 men days white help left voice free look
# Topic 14:
# theresistance notmypresident lovetrumpshate strongertogether trumpleaks putinpuppet stopsessions presidentbannon impeachtrump stoppresidentbannon
# Topic 15:
# sign stand org stop inauguration change ppl moveon sorry petitions
# Topic 16:
# watch proud strong ladies took theresistence trumphotels standing powerful law
# Topic 17:
# ow love media art start feel california social hate house
# Topic 18:
# equality man think menra1 sessions doesn devos 10actions100days represent civilrights
# Topic 19:
# march womens washington womensmarchonwashington movement signs post photos work reflections
#
# Performing LDA on Cluster 1...
# Topic 0:
# video black liked murderers theocrats gender ahmmydyyxxk america equality feminist
# Topic 1:
# womensmarchonwashington say didn openly power nasty liberal said podcast better
# Topic 2:
# muslimban trump resist theresistance potus nobannowall aclu realdonaldtrump alternativefacts watch
# Topic 3:
# pussy hats ow hope post feminism whyimarch hat fight ugly
# Topic 4:
# hey freedom thoughtoftheday thespacebetweenus web 29 30 org hard work
# Topic 5:
# paper latest 11e6 edition_id daily thanks 0cc47a0d164b 9e2c speech immigrationban
# Topic 6:
# weekend use photos womensmarchaustin voice txlege action keeping stopsessions 10actions100days
# Topic 7:
# law female sharia linda genital mutilation march victim news inauguration
# Topic 8:
# sally yates uber driving handle forget ladies randyprine joyannreid demanding
# Topic 9:
# march sign womens washington resistance org sorry ppl imarchwithlinda new
# Topic 10:
# rights protests shirt fight entry huffingtonpost marched jennifer perfect sentoomey
# Topic 11:
# love rant change maga people beast retweeted bass r5dhcxbo9ug bassthebeastnyc
# Topic 12:
# just protest nobannowall right signs agree muslimbanprotest johncornyn tedcruz america
# Topic 13:
# march rebekahworsham real photo 824420406710992896 pjnet thankavet sot mt life
# Topic 14:
# nobannowall stat stand think majority blacklivesmatter matter stoppresidentbannon care things
# Topic 15:
# 808 cruz noon travis ted tomorrow join houston ones idiotic
# Topic 16:
# week better boise organized senior hillaryclinton deserves profile add climatechange
# Topic 17:
# yes recognize permitted prayer happened fail ten_gop super ow trumphotels
# Topic 18:
# time 100 voices postcard heard history send senators itâ tter
# Topic 19:
# marchforlife love man statement story proud prochoice video dc participants
#
# Performing LDA on Cluster 2...
# Topic 0:
# sign ppl inauguration 3x bigots petitions imarchwithlinda sorry org onetruechange
# Topic 1:
# theresistance indie ff gopwomen latinas africanamerican dems asian right stat
# Topic 2:
# way vote white march liberal country notmypresident conservative thing control
# Topic 3:
# resist resistance resisttrump org protest nobannowall little bannon whyimarch refugees
# Topic 4:
# thought ridiculous post looked amymek look want proud week weekend
# Topic 5:
# senators whyimarch time 100 send postcard history heard source twi
# Topic 6:
# tell marched ve stop pro choice stand sweetsamba ahead walk
# Topic 7:
# realdonaldtrump latest resistance things paper 9e2c edition_id 11e6 tweetsfrommsb 0cc47a0d164b
# Topic 8:
# pamela_moore13 825836156688429056 notice looked girls dems ar muslimban asian 826410839704031232
# Topic 9:
# muslimban trump people resist resistance maybe participants love protest airport
# Topic 10:
# rebekahworsham mt pjnet sot real 824420406710992896 thankavet march photo america
# Topic 11:
# watch etsy womensmarchonwashington feminism dc march atlantamarch want vid relevant
# Topic 12:
# chaos chat ow bannon 128 episode film end things womensmarchal
# Topic 13:
# just stories pics mn 2k8cmrp protestors share willpeeblessmn savannah washington
# Topic 14:
# moments œmassive los jonriley7 8230 angelesâ 38311232991232 truly nodapl common
# Topic 15:
# march womens impeachtrump week protests movement does marchforlife2017 womenâ planned
# Topic 16:
# leader anti trump law day sex activist portland sallyyates blm
# Topic 17:
# marched southern secret selfesteem changing victoria values tinyurl bodyimage jygk3n5
# Topic 18:
# pussy bloggersoc refugees hats world sessions stopsessions fingerprints yates place
# Topic 19:
# nobannowall americans standing trumphotels stoptrump stoppresidentbannon sciencemarch aclu fellow deleteuber
#
# Performing LDA on Cluster 3...
# Topic 0:
# time history 100 heard senators voices send source postcard tter
# Topic 1:
# protests good taking videos marchforlife ht maga watching 10actions100days trumpwins
# Topic 2:
# love world linda sarsour organizer just vagina speakers mess hylton
# Topic 3:
# resistance rights support sharia theresistance moveon notmypresident indivisible human today
# Topic 4:
# broemmel ref resist girl amazon keywords qid sr utf8 bonfils
# Topic 5:
# muslimban resist nobannowall trump sign inauguration news sciencemarch share stop
# Topic 6:
# yes vote whyimarch man little hylton donna 1st speaker empowerwomen
# Topic 7:
# resist realdonaldtrump watch potus nomuslimban nobannowall know look etsy million
# Topic 8:
# life ebay energy marches marchforlife week nodapl went video itm
# Topic 9:
# nobannowall urbanebox month urbane heels goodmorning protest womenstyle muslimban stand
# Topic 10:
# trumpismypresident video feminism trumptrain muslimban 825912669232304130 stonewall_77 islam muslim 100percentfedup
# Topic 11:
# march womens fight washington org facts daughters feminists sciencemarch dc
# Topic 12:
# whyimarch postcards writing mmflint rights believe westandunited 825814892158578688 lovearmy country
# Topic 13:
# resist trump stoppresidentbannon protest stat theresistance potus maga muslimban senatedems
# Topic 14:
# weekend politics nc speech government newsobserver news hey entry huffpost
# Topic 15:
# latest 11e6 paper right edition_id google sciencemarch en search client
# Topic 16:
# way dc post coming marcorubio senbillnelson 10actions100days mail hotel past
# Topic 17:
# people media thing millions maga thinking joke feminism 22 social
# Topic 18:
# ow asking wmw womenwhohaveinspiredme yes men stronger stop free pay
# Topic 19:
# just lol want hate best important natalac natalac74 masculinist public
